# %% [markdown]
# # importing dataset

# %%
import pandas as pd
import numpy as np
import sklearn

# reading the dataset in the given csv file

file_data = pd.read_csv ('Churn_Modelling.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
file_data.head()
file_data.tail()

plt.boxplot (file_data['Age'])
sns.boxplot (file_data['Tenure'])
sns.displot (file_data['Age'])
sns.lineplot (x = 'Age', y = 'Balance', data = file_data)
sns.barplot (x = 'Age', y = 'Balance', data = file_data)
sns.countplot (x = 'Age', data = file_data)
corr_matrix = file_data.corr()
sns.heatmap (corr_matrix)
file_data.describe()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# ...

# %%
file_data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
file_data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.boxplot (file_data['Age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
qnt=file_data.quantile(q=[0.25,0.75])
qnt
IQR =qnt.loc[0.75]-qnt.loc[0.25]
IQR
upper_extreme=qnt.loc[0.75]+1.5*IQR
upper_extreme
lower_extreme=qnt.loc[0.25]-1.5*IQR
lower_extreme
# Out:
# RowNumber         -4.998500e+03
# CustomerId         1.544147e+07
# CreditScore        3.830000e+02
# Age                1.400000e+01
# Tenure            -3.000000e+00
# Balance           -1.914664e+05
# NumOfProducts     -5.000000e-01
# HasCrCard         -1.500000e+00
# IsActiveMember    -1.500000e+00
# EstimatedSalary   -9.657710e+04
# Exited             0.000000e+00
# dtype: float64

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer (missing_values=np.nan, strategy='main')
file_data[file_data['Age'] > 88]
file_data[file_data['Age'] > 92]
file_data['Age'] = np.where (file_data['Age'] > 88, file_data['Age'].mean(), file_data['Age'])
file_data[file_data['Age'] > 88]
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
from sklearn.preprocessing import LabelEncoder
labelObj = LabelEncoder()
file_data['Surname'] = labelObj.fit_transform (file_data['Surname'])
file_data.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602     1115          619    France  Female  42.0
# 1          2    15647311     1177          608     Spain  Female  41.0
# 2          3    15619304     2040          502    France  Female  42.0
# 3          4    15701354      289          699    France  Female  39.0
# 4          5    15737888     1822          850     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
y = file_data['Exited']
x = file_data.drop(columns=['Exited'], axis = 1)
names = x.columns
names
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary'],
#       dtype='object')

# %%
from sklearn.preprocessing import scale
x
x = pd.DataFrame (x, columns=names)
x.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602     1115          619    France  Female  42.0
# 1          2    15647311     1177          608     Spain  Female  41.0
# 2          3    15619304     2040          502    France  Female  42.0
# 3          4    15701354      289          699    France  Female  39.0
# 4          5    15737888     1822          850     Spain  Female  43.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary
# 0        101348.88
# 1        112542.58
# 2        113931.57
# 3         93826.63
# 4         79084.10

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)
x_train.shape
# Out:
# (8000, 13)
